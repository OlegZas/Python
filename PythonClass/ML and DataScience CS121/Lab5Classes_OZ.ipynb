# %%
import os
os.getcwd() 
os.chdir(r'C:\Users\zasuk\Desktop\ELAC\Python 121 ML and DataScience\Exercises\Lab5')

# %% [markdown]
# ### Point, Square, Cube

# %%
pointcode = '''import math 

#Phase 1 Points 
class Point: # not sure if i am supposed to change this example. 
    """Oleg's private class initializing Point object"""
    def __init__(self, x, y):

        self._X = x # "ideally coordinates should be x and y" so ill keep as they are 
        self._Y = y #'capitalized since they should be constant and hide them with underscore.' 


    def distance(self, other):
        """Method to find distance from point X to Y"""
        return round(math.sqrt((self._X - other._X)**2 + (self._Y - other._Y)**2),2) # rounding bonus
# s.x - o.x is the change in xaxis ; s.y - o.y change in y axis. 
    #then square and add since sum of a and b squared = c squared (hypothenuse)
    # so we get the sum of squares of horizontal nad vert differences 
    # then sqrt to solve for c - distance (hypotenuse)

    def slope(self, other):
        """Public mehtod to find the slope of the line"""
        return (other._Y - self._Y) / (other._X - self._X)'''

with open('point.py', 'w') as file:
    file.write(pointcode)

# %%
import math 

#Phase 1 Points 
class Point: # not sure if i am supposed to change this example. 
    """Oleg's private class initializing Point object"""
    def __init__(self, x, y):

        self._X = x # "ideally coordinates should be x and y" so ill keep as they are 
        self._Y = y #'capitalized since they should be constant and hide them with underscore.' 


    def distance(self, other):
        """Method to find distance from point X to Y"""
        return round(math.sqrt((self._X - other._X)**2 + (self._Y - other._Y)**2),2) # rounding bonus
# s.x - o.x is the change in xaxis ; s.y - o.y change in y axis. 
    #then square and add since sum of a and b squared = c squared (hypothenuse)
    # so we get the sum of squares of horizontal nad vert differences 
    # then sqrt to solve for c - distance (hypotenuse)

    def slope(self, other):
        """Public mehtod to find the slope of the line"""
        return (other._Y - self._Y) / (other._X - self._X)

# %%
squarecode = """from point import Point # importing Point class # will create instances later 
import math

class Square:
    '''instances of POINT class above as propreties to create a square'''

    def __init__(self, first, second):
        '''initializing square'''    
        self._FIRST = first # internal attribute of sq
        self._SECOND = second 

    def length(self): #method to calculate the side lenght 
        return abs(self._FIRST._X - self._SECOND._X) #horizontal distance between the two 
# have to use absolute value function otherwise the results are nonsencical down the line 

    def area(self): #now just need to find the area 
        '''Returning area of the square'''
        side = self.length() #calling length method hre 
        return side ** 2

    def perimeter(self):
        side = self.length()
        return 4 * side"""

with open("square.py", "w") as file:
    file.write(squarecode)

# %%
from point import Point # importing Point class # will create instances later 
import math

class Square:
    """instances of POINT class above as propreties to create a square"""

    def __init__(self, first, second):
        '''initializing square'''    
        self._FIRST = first # internal attribute of sq
        self._SECOND = second 

    def length(self): #method to calculate the side lenght 
        return abs(self._FIRST._X - self._SECOND._X) #horizontal distance between the two 
# have to use absolute value function otherwise the results are nonsencical down the line ---- NOT THE CASE, had an issue with the calculation here, that's why it was wrong
    def area(self): #now just need to find the area 
        '''Returning area of the square'''
        side = self.length() #calling length method hre 
        return side ** 2

    def perimeter(self):
        side = self.length()
        return 4 * side

# %%
cubecode = """
from square import Square # importing Point class # will create instances later 
import math

class Cube: 

    def __init__(self, square):
        '''cube with square object'''
        self._SQUARE = square

    def volume(self):
        side = self._SQUARE.length()
        return side ** 3

    def surfacearea(self):
        side = self._SQUARE.length()
        return 6*(side **2)
"""

with open("cube.py", "w") as file:
    file.write(cubecode)

# %%
from square import Square # importing Point class # will create instances later 
import math

class Cube: 

    def __init__(self, square):
        '''cube with square object'''
        self._SQUARE = square

    def volume(self):
        side = self._SQUARE.length()
        return side ** 3

    def surfacearea(self):
        side = self._SQUARE.length()
        return 6*(side **2)

# %%
from point import Point
from square import Square
from cube import Cube # importing all 
import os
os.getcwd() 
os.chdir(r'C:\Users\zasuk\Desktop\ELAC\Python 121 ML and DataScience\Exercises\Lab5')  # my directory 

# giving points x and y
p1 = Point(3,2 ) # could take care of negatives by using absolute function (or similar) but not part of the instructions 
p2 = Point(8, 4)

# Distance
print("Distance:", p1.distance(p2))  

# Slope
print("Slope:", p1.slope(p2))  

# SQuare with the points from above 
square = Square(p1, p2)
#tests 
print("Square LLength:", square.length())
print("Square Area:", square.area())
print("Square Perimeter:", square.perimeter())


cube = Cube(square) #cube using square above
print("Volume:", cube.volume()) 
print("Surface Area:", cube.surfacearea())
#m made adjustmnets to square methods and results make sense now
# Out:
# Distance: 5.39
# Slope: 0.4
# Square LLength: 5
# Square Area: 25
# Square Perimeter: 20
# Volume: 125
# Surface Area: 150

# %% [markdown]
# ### Example with POINT, CIRCLE, SPHERE
# - this one is given, very good

# %%
import math 

#Phase 1 Points 
class Point: # not sure if i am supposed to change this example. 
    """Oleg's private class initializing Point object"""
    def __init__(self, x, y):

        self._X = x # "ideally coordinates should be x and y" so ill keep as they are 
        self._Y = y #'capitalized since they should be constant and hide them with underscore.' 


    def distance(self, other):
        """Method to find distance from point X to Y"""
        return math.sqrt((self._X - other._X)**2 + (self._Y - other._Y)**2)
# s.x - o.x is the change in xaxis ; s.y - o.y change in y axis. 
    #then square and add since sum of a and b squared = c squared (hypothenuse)
    # so we get the sum of squares of horizontal nad vert differences 
    # then sqrt to solve for c - distance (hypotenuse)

    def slope(self, other):
        """Public mehtod to find the slope of the line"""
        return (other._Y - self._Y) / (other._X - self._X)

#Phase 2 Circle 
class Circle:

    def __init__(self, center, edgepoint):
        self._CENTER = center
        self._EDGE = edgepoint


    def area(self):

        return math.pi * (self._CENTER.distance(self._EDGE) ** 2)
# this is a radius of the cicle - (self._CENTER.distance(self._EDGE) 

    def perimiter(self):

        return 2 * math.pi * self._CENTER.distance(self._EDGE) 

#Phase 3 SPhere
class Sphere:
    def __init__(self, circle):
        self._CENTRALCIRCLE = circle


    def volume(self):

        return (4 / 3) * math.pi * (((self._CENTERALCIRCLE._perimiter()/math.pi)/4) ** 3)


    def surface_area(self):
        return 4 * (self._CENTERALCIRCLE.area())
