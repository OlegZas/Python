# %% [markdown]
# # Lab 2: Operator Expressions

# %% [markdown]
# ## My Practice:
# ### Employee Salaries
# NOTE: dictionaries are indexed by key strings after Python 3.7

# %%
#I will continute my Python (and Spansih) prcactice. 
#a dictionary that contains salaries of the employees with very unique names. 
salarios = {"protesta ensenar": 175000, "contento sabroso" : 85000, "linda cuero" : 145000, "vidrio piedra" : 99000}
total_salaries = sum(salarios.values()) # getting sum, but not using + instead the built-in function; 
salary_range = max(salarios.values()) - min(salarios.values()) # here is the minus. using min and max functions here 
twoHighest = salarios["linda cuero"] + salarios["vidrio piedra"] # here is the plus 
Averagesalary = sum(salarios.values()) / len(salarios) # division .. or can use average fucntion 
AnnualIncrease = 0.1
AfterAnnualIncrease = salarios["protesta ensenar"] * (1+AnnualIncrease) # multiplied here 
print("range of salaries: %d, total salaries: %d, two highest salaries combined: %f, averagesalary: %f, After getting an increase, protesta ensenar started earning: %d" 
      %(salary_range,total_salaries,twoHighest, Averagesalary,AfterAnnualIncrease))
# PS. next time Ill print in separate lines. 
# PS. just combining python with my Spansih practice 

#Bonus concatenations as metnioned in the lecture: 
# Python doesn't have built in concat function ... so + can be used, also f-stirng which i used in previous practice 
name = "Pablo"
lastName = "Stepanenko"
employeeMerge = name + " " + lastName 
print(employeeMerge)
# Out:
# range of salaries: 90000, total salaries: 504000, two highest salaries combined: 244000.000000, averagesalary: 126000.000000, After getting an increase, protesta ensenar started earning: 192500
# Pablo Stepanenko

# %% [markdown]
# ## Think about the program:

# %% [markdown]
# I do not know how I will do it yet, but by the end of this class (as part of the class or separately) I would like to create an app that :
# 1. Most likely a web app
# 2. User sends an http request -- ex: name input (or something else)
# 3. THe app is connected to the database in BigQuery, Reshift, Snowflake, or any warehouse.
# 4. From the database, based on the name, an output is sent to the user.
#
# I will start working on it next week or the one after next. If everything goes smoothly, I'll try to make it a bit more complicated.
