# %% [markdown]
# 6/25/25

# %% [markdown]
# # <u>**Lab 2B SLO**</u>

# %% [markdown]
# ### Notes
# - I installed **Anaconda** and am using **Jupyter Notebook**.
# - I understand the basics of Python.
#
# ### **Goals**
# To complete this lab, I will:
# 1. Generate simple code that produces a couple of errors.
#    > Explain each error and how to fix it.
# 2. Generate errors using control structures, methods, and functions (e.g., `if`, `else`, `for`, `while`, etc.).
#    > Explain the errors and how to troubleshoot them.

# %% [markdown]
# ### **Numero Uno**

# %%
prin amicable 
''' This contains an error: 
1. The  print function is misspelled. 
2. The function's ( ) are missing - in Python, they seem to be mandatory - not a fan of this 
3. Amicable is a string that is missing quotation marks that are required for strings
Bonus: I also forgot to close the ''' which denotes a string... ooops... what a mess
# Out:
#   Cell In[21], line 1
#     prin amicable
#          ^
# SyntaxError: invalid syntax

# %%
print 'amicable'
# already improving! no more confusing ''' '''  instead it's time for # 
# here print function is written corectly and the string has ' ' 
# Problem: function's ( ) are still missing .. but getting close now, I am proud of you Oleg :)
# Out:
#   Cell In[22], line 1
#     print 'amicable'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ('ami'cable')
# getting creative now; I like this one 
# Python is confused, he has no idea that there is an apostrophe and thinks there are three quotation marks (are there?)
# Out:
#   Cell In[23], line 1
#     print ('ami'cable')
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ("ami'cable means friendly")
#ah here we are! 
#overview of fixes: 
#1. print fucntion spelling 
#2. ( ) perentheses used for the print function 
#3. use quotation marks for the stirngs 
#4. use double quotes to encapsulate the string and single quotes to print that single quote 
#5. Solved! It's fun to entertain myself :)
# Out:
# ami'cable means friendly

# %% [markdown]
# ### **Numero Dos**

# %% [markdown]
# 6/26/25

# %%
# Creating a Loop 
# learn how to do a user input here! 

# create some variables 
la_comoda = "chest of drawers" 
el_cuarto = "room/quarter" 
while  len.la_comoda > len.el_cuarto :
    print ("El dormitorio means bedroom not %s or %s"%(la_comoda, el_cuarto))
else 
    print ("El tocador is a dresser. El armario means closet") 

#Errors (there were more, but i fixed them already, then realized that errors are the point of this assignment. 
#len. is not a proper way to use a method in Python, it should be len(dfd)
#Important: the loop is endless! el_cuarto will never be = la_comobda because there is no increment
#I keep forgetting to add : after while or else in Python. some day i will remember.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 7
#       5 la_comoda = "chest of drawers"
#       6 el_cuarto = "room/quarter"
# ----> 7 while  len.la_comoda > len.el_cuarto :
#       8     print ("El dormitorio means bedroom not %s or %s"%(la_comoda, el_cuarto))
#       9 else :
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'la_comoda'

# %%
la_comoda = "chest of drawers" 
el_cuarto = "room/quarter" 
while  len(la_comoda) > len(el_cuarto) :
    print ("El dormitorio means bedroom not %s or %s"%(la_comoda, el_cuarto))
    el_cuarto += "1" # can't incrmeent integer to a string, so using a string 1 here 
else :
    print ("El tocador is a dresser. El armario means closet")
# Out:
# El dormitorio means bedroom not chest of drawers or room/quarter
# El dormitorio means bedroom not chest of drawers or room/quarter1
# El dormitorio means bedroom not chest of drawers or room/quarter11
# El dormitorio means bedroom not chest of drawers or room/quarter111
# El tocador is a dresser. El armario means closet

# %%
# Creating an if, if-else, else statement 

#seguimos o continuamos! 

dresser = "el tocador" 
# First time doing user input in Python: 
closet = input("so simple that the closet feel's disappointed :")
print(f"printing input here : {closet})
# Out:
#   Cell In[14], line 8
#     print(f"printing input here : {closet})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 8)

# %%
# This one was easy to fix, above forgot to add the closing quotation mark.  
closet = input("so simple that the closet feel's disappointed :")
print(f"printing input here : {closet}")
# Out:
# so simple that the closet feel's disappointed : nice
# printing input here : nice

# %%
#user input with an integer 
enigmatic = int(input("trying number input: "))
print("Let's see if this will work : %d"%(enigmatic))
# Out:
# trying number input:  wow
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 #user input with an integer
# ----> 2 enigmatic = int(input("trying number input: "))
#       3 print("Let's see if this will work : %d"%(enigmatic))
#
# ValueError: invalid literal for int() with base 10: 'wow'

# %%
# It worked with the first attempt! But of course it's expecting an integer: 
enigmatic = int(input("trying number input: "))
print("Let's see if this will work : %d"%(enigmatic))
# Out:
# trying number input:  343
# Let's see if this will work : 343

# %% [markdown]
# Note: of course i am using outside recources for all of these. However, i am trying to get them into the system, spot the patterns, and memorize the syntax. Often, i am attempting to type from memory or using 'logic'.

# %%
# Now it's time to review for loop: 

enigmatic = "mysterius" 
for char(i) in enigmatic : 
    print("My guess is there is no char method")
else : 
    print("The end of practice")
# Out:
#   Cell In[19], line 4
#     for char(i) in enigmatic :
#         ^
# SyntaxError: cannot assign to function call

# %%
enigmatic = "mysterius" 
for i in enigmatic : 
    print("My guess is there is no char method")
else : 
    print("The end of practice")
# Out:
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# My guess is there is no char method
# The end of practice

# %% [markdown]
# ^^ I overthought that one. tried to use char method, but that's not necessary because i represents a character when dealing with strings.
