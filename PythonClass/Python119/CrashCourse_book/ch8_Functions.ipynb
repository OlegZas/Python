# %% [markdown]
#                             7/11/2025
# # ch8 Functions

# %%
# Passing information to a Function 

def toil(username):
    print(f"hola mola_toil means to work hard or nound: hard work; but the username is: {username.title()}")#title just a method that sets object to Sentence Case 
toil('oleg')
# Out:
# hola mola_toil means to work hard or nound: hard work; but the username is: Oleg

# %% [markdown]
# ### Defualt Values

# %%
def scornful(nonchalant = 'calm, peaceful, not worried', ramification = 'consequence'):
    print(f"These are default values, nonchalant means: {nonchalant.upper()}, while ramification means: {ramification.upper()}")
scornful()
# Out:
# These are default values, nonchalant means: CALM, PEACEFUL, NOT WORRIED, while ramification means: CONSEQUENCE

# %% [markdown]
# 8-5. Cities: Write a function called describe_city() that accepts the name of a city and its country. The function should print a simple sentence, such as Reykjavik is in Iceland. Give the parameter for the country a default value. Call your function for three different cities, at least one of which is not in the default country.

# %%
def describe_city(city="reykjavik",country="iceland"):
    print(f"The city {city.title()} is located in {country.title()}")
describe_city(city="Oleg")
# Out:
# The city Oleg is located in Iceland

# %% [markdown]
# ### Return Values
# - print is used to display the output directly
# - return is used to process data and store it so it can be returned

# %%
def formatted(first_name, last_name): 
    full_name = f"{first_name}{last_name}"
    return full_name.title()
musician = formatted("Oz","python")
print(musician)

#********** Optional argument: 
def formatted(first_name, last_name,middlename =''): # PARAMETER WITH AN ARGUMENT MUST BE AT THE END 
    full_name = f"{first_name}{last_name}"
    return full_name.title()
musician = formatted("Oz","python")
print(musician)
# Out:
# Ozpython
# Ozpython
