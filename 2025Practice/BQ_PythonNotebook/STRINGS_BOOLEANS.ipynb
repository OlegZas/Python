# %% [markdown]
# Boolean

# %%
print(1340 > 39)
print(20 == 19)
print(1 < 434)
# Out:
# True
# False
# True

# %%
f = 323
b = 11

if b > f:
  print("b is greater than f")
else:
  print("b is not greater than f")
# Out:
# b is not greater than f

# %%
print(bool("Any string is true"))
print(bool(0)) # any number is true except for 0
# Out:
# True
# False

# %% [markdown]
# <h2>Functions can return boolean values</h2>

# %%
def bolFunction() :
  return True

print(bolFunction())
# Out:
# True

# %%
#Print "OZ!" if the function returns True, otherwise print "COYS!":

def bolFunction2():
  return True

if bolFunction2():
  print('OZ!')
else:
  print('COYS!')
# Out:
# OZ!
