# %% [markdown]
# **Python Sets**
# - A set is a data structure in Python used to hold multiple elements within a single variable.
#
# - It is one of the four core data types in Python, alongside List, Tuple, and Dictionary, each serving different purposes and having unique characteristics.
#
# - A set is an unordered, immutable* collection that does not allow indexing.

# %% [markdown]
# myset = {"apple", "banana", "cherry"}
